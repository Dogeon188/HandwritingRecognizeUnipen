# %%
# import libraries
from utils.preprocess import *
from utils.demonstration import *

# load dataset
dataset = load_unipen_dataset().shuffle(10000)

# %%
dataset.cardinality().numpy()
# Out:
# 62382

# %%
for e in dataset.take(1):
    code = e[1]["code"].numpy()
    plot_digit(e[0].numpy(), chr(code))
